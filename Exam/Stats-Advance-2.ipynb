# %% [markdown]
# <h1>Basic</h1>

# %% [markdown]
# 1. What is hypothesis testing in statistics

# %% [markdown]
# <b>Ans-</b> Hypothesis Testing in statistics is testing that the claim made for a data is true or not.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis

# %% [markdown]
# <b>Ans-</b> Null Hypothesis is that the claim made like for example a company claims that they have Average of 50 grams of protein in there bar, Now Null Hypo is --> h0 = 50, now here an medical lab came in says there is not 50 grams of protein so alternate hypo is --> h1 != 50.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important.

# %% [markdown]
# <b>Ans-</b> In hypothesis testing, the significance level (denoted by α, alpha) is the probability of rejecting the null hypothesis when it is actually true. It represents the researcher's willingness to accept a Type I error, which is falsely rejecting a true null hypothesis. It's a crucial threshold for determining statistical significance, helping researchers decide whether observed results are likely due to chance or a real effect.

# %% [markdown]
# 4.  What does a P-value represent in hypothesis testing

# %% [markdown]
# <b>Ans-</b> the p-value is the probability of observing data as extreme as what you have, assuming the null hypothesis is true

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing

# %% [markdown]
# <b>Ans-</b> The p-value only tells you how likely the data you have observed is to have occurred under the null hypothesis. If the p-value is below your threshold of significance (typically p < 0.05), then you can reject the null hypothesis, but this does not necessarily mean that your alternative hypothesis is true.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing

# %% [markdown]
# <b>Ans-</b> Type 1: it is an error where null hypo is actually true but we reject it, and type 2: here the null hypo is false but we fail to reject it.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing

# %% [markdown]
# <b>Ans-</b> One tail test here we are only checkinig where is value is at one side like we only say ">" "<" in altenate hypo and in two tail test value can be both side so alternate hype "!="

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing

# %% [markdown]
# <b>Ans-</b> A z-test is a statistical hypothesis test used to determine if there's a significant difference between a sample mean and a population mean, or between the means of two independent samples, when the population variance is known or the sample size is large. It's typically used when dealing with data that follows a normal distribution.

# %% [markdown]
# 9.  How do you calculate the Z-score, and what does it represent in hypothesis testing

# %% [markdown]
# <b>Ans-</b> Lets take any example. and Z-Score = (x_bar - mu) / (p_sigma / n ** 0.5)

# %% [markdown]
# A tire company claims that its tires last at least 60,000 km on average.
#
# An independent lab thinks the average is actually less than that.
#
# They test a sample of 49 tires and find:
#
# Sample mean = 58,900 km
#
# Standard deviation = 2,100 km
#
# Significance level = 0.01

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

population_mean = 60000
sample_mean = 58900
n = 49
population_sigma = 2100
alpha = 0.01

z = (sample_mean - population_mean) / (population_sigma / (n ** 0.5))
z_critical = norm.ppf(alpha)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution', color='blue')

x_crit = np.linspace(-4, z_critical, 100)
y_crit = norm.pdf(x_crit)
plt.fill_between(x_crit, y_crit, color='red', alpha=0.4, label='Critical Region (α = 0.01)')

plt.axvline(z, color='black', linestyle='--', label=f'Z-stat = {z:.2f}')
plt.axvline(z_critical, color='red', linestyle='--', label=f'Z-critical = {z_critical:.2f}')

plt.title('Z-Test: One-Tailed Test (Left Tail)')
plt.xlabel('Z value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution

# %% [markdown]
# <b>Ans-</b> it is a probability distribution used in statistics, particularly when dealing with small sample sizes or when the population standard deviation is unknown.  It is preferred over the normal distribution in these situations because it accounts for the increased uncertainty associated with estimating population parameters from limited data.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test

# %% [markdown]
# <b>Ans-</b> The main difference between them is of standard deviation, Wherein Z Test in formula standard deviation is used a of population and in T Test we use Standard deviation of Sample. Both have different table. Also in Z Test sample n > 30, as in T Test sample n <= 30

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing

# %% [markdown]
# <b>Ans-</b> T Test in hypothesis testing is an method where we check that claim made is true or not also keeping in mind sample size <= 30, T-Score = ((x_bar - mu) / (s / (n ** 0.5))) and further check the value in df = n - 1. For Example.

# %% [markdown]
# A company claim they have 13g of protein in there milk pouch.
# We checking are the saying true or not.
# Number of Date collected: 12
# Sample Mean: 15g
# Sample Standard Deviation: 3g
# Level Of Significance: 0.05

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

mu = 13
x_bar = 15
n = 12
s = 3
df = n - 1
alpha = 0.05

t_stats = (x_bar - mu) / (s / (n ** 0.5))

t_crit_right = t.ppf(1 - alpha / 2, df)
t_crit_left = t.ppf(alpha / 2, df)

x = np.linspace(-4, 4, 1000)
y = t.pdf(x, df)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='t-distribution (df=11)', color='blue')

plt.fill_between(x, y, where=(x <= t_crit_left), color='red', alpha=0.4, label='Left Critical Region')
plt.fill_between(x, y, where=(x >= t_crit_right), color='red', alpha=0.4, label='Right Critical Region')

plt.axvline(t_stats, color='black', linestyle='--', label=f't-stat = {t_stats:.2f}')

plt.axvline(t_crit_left, color='red', linestyle='--', label=f't-critical = {t_crit_left:.2f}')
plt.axvline(t_crit_right, color='red', linestyle='--')

plt.title('Two-Tailed t-Test Visualization')
plt.xlabel('t value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing

# %% [markdown]
# <b>Ans-</b> Both Z-tests and T-tests are used in hypothesis testing to compare means, but they differ in their assumptions and when they are most appropriate. Z-tests are used when the population standard deviation is known and the sample size is large (typically 30 or more). T-tests are used when the population standard deviation is unknown and/or the sample size is small (typically less than 30).

# %% [markdown]
# 14.  What is a confidence interval, and how is it used to interpret statistical results

# %% [markdown]
# <b>Ans-</b> Confidence Interval is an interval where we say that value may vary we it might be in between some interval, It give as an upper hand hen just say a point estimate whic might have higher chance of getting rejected.

# %% [markdown]
# 15.  What is the margin of error, and how does it affect the confidence interval

# %% [markdown]
# <b>Ans-</b> Margin of error helps to calculate the interval value with help of formula which further we put in the Confidence interval to calculate the interval.

# %% [markdown]
# 16.  How is Bayes' Theorem used in statistics, and what is its significance

# %% [markdown]
# <b>Ans-</b> Bayes' theorem is a fundamental concept in probability and statistics that provides a way to update the probability of an event based on new evidence. It allows statisticians to combine prior knowledge with observed data to refine their understanding of probabilities, making it a crucial tool for inference and decision-making.

# %% [markdown]
# 17.  What is the Chi-square distribution, and when is it used

# %% [markdown]
# <b>Ans-</b> It is an probability disribution that describe the distribution of a sum of squares of k random variable, it is used when population data is not present.

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied

# %% [markdown]
# <b>Ans-</b> It is a one tail test as numbers are squared here we compare expected with observed and try to see or check is difference to big or it is just random. It is applied with a formual sigma (Obeserve - Expected)^2/Expected. Then for alpha we get critical point from table and check our chi stats is greater or not if greater then we reject it if lesser the we fail to reject.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import chi2

data_points = ['1', '2', '3', '4', '5', '6']
observed = np.array([12, 9, 11, 13, 8, 7])
expected = np.array([10, 10, 10, 10, 10, 10])
df = len(data_points) - 1

chi_square_stat = np.sum((observed - expected) ** 2 / expected)

critical_value = chi2.ppf(0.95, df)

x = np.linspace(0, 20, 300)
y = chi2.pdf(x, df)

plt.plot(x, y, label='Chi-Squared Distribution', color='blue')
plt.axvline(chi_square_stat, color='black', linestyle='--', label=f'Chi-Square Stat = {chi_square_stat:.2f}')
plt.axvline(critical_value, color='red', linestyle='--', label=f'Critical Value = {critical_value:.2f}')
plt.fill_between(x, y, where=(x >= critical_value), color='red', alpha=0.4, label='Critical Region (α = 0.05)')

plt.title('Chi-Square Test: Observed vs Critical Value')
plt.xlabel('Chi-Square Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing

# %% [markdown]
# <b>Ans-</b> it is a probility distribution that is useful in the context of comparing the variance of two or more sample and it is right skewed don't take negative values, It is used to compare variances

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions

# %% [markdown]
# <b>Ans-</b> It is an test which follows F-Distribution and it is used to compare means of two or more groups whereas it is used for two or more groups. Assumptions: For where the sample are drawn they should be in normal distribution, The sample should be independent and should be random, No outlliers should be present, Homogenity of variance should be there.

# %% [markdown]
# 21. What are the different types of ANOVA tests

# %% [markdown]
# <b>Ans-</b> 1. One-Way ANOVA
# Compares means of 3+ groups
#
# 1 independent variable (factor)
#
# Ex: Do 3 diets lead to different weight loss?
#
# 2. Two-Way ANOVA (Factorial)
# 2 independent variables
#
# Tests for:
#
# Main effect of A
#
# Main effect of B
#
# Interaction effect A × B
#
# Ex: Does exercise type and diet type affect fat loss?
#
# 3. Repeated Measures ANOVA
# Same subjects tested multiple times
#
# 1 independent variable, measured repeatedly
#
# Ex: Student performance before, mid, after training

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing

# %% [markdown]
# <b>Ans-</b>  It uses the F-distribution, and the result is an F-statistic, which helps you decide whether to reject or fail to reject the null hypothesis.

# %% [markdown]
# <h1>Pratical</h1>

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results

# %% [markdown]
# <b>Ans-</b>A tire company claims that its tires last at least 60,000 km on average.
#
# An independent lab thinks the average is actually less than that.
#
# They test a sample of 49 tires and find:
#
# Sample mean = 58,900 km
#
# Standard deviation = 2,100 km
#
# Significance level = 0.01

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

population_mean = 60000
sample_mean = 58900
n = 49
population_sigma = 2100
alpha = 0.01

z = (sample_mean - population_mean) / (population_sigma / (n ** 0.5))
z_critical = norm.ppf(alpha)

x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Standard Normal Distribution', color='blue')

x_crit = np.linspace(-4, z_critical, 100)
y_crit = norm.pdf(x_crit)
plt.fill_between(x_crit, y_crit, color='red', alpha=0.4, label='Critical Region (α = 0.01)')

plt.axvline(z, color='black', linestyle='--', label=f'Z-stat = {z:.2f}')
plt.axvline(z_critical, color='red', linestyle='--', label=f'Z-critical = {z_critical:.2f}')

plt.title('Z-Test: One-Tailed Test (Left Tail)')
plt.xlabel('Z value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

if z < z_critical:
    print("Reject the null hypothesis: The sample mean is significantly less than the population mean.")
# Out:
# Reject the null hypothesis: The sample mean is significantly less than the population mean.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

# %%
import numpy as np
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import scipy as stats
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

group_A = np.random.normal(loc=70, scale=5, size=30)
group_B = np.random.normal(loc=73, scale=5, size=30)

t_stat, p_value = ttest_ind(group_A, group_B)
print("Group A Mean:", round(np.mean(group_A), 2))
print("Group B Mean:", round(np.mean(group_B), 2))
print(f"T-statistic = {t_stat:.4f}")
print(f"P-value = {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀: Significant difference between the groups.")
else:
    print("Fail to reject H₀: No significant difference.")
# Out:
# Group A Mean: 71.41
# Group B Mean: 71.97
# T-statistic = -0.5945
# P-value = 0.5545
# Fail to reject H₀: No significant difference.

# %% [markdown]
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean

# %%
from scipy.stats import norm

population_mean = 70
population_sigma = 5

sample_mean = 71.6
sample_n = 36
z_stats = (sample_mean - population_mean) / (population_sigma / np.sqrt(sample_n))

p_value = 2 * (1 - norm.cdf(z_stats))
print(f"Z-statistic = {z_stats:.4f}")
print(f"P-value = {p_value:.4f}")

alpha = 0.05
if alpha < p_value:
    print("Reject Null hypothesis")
else:
    print("Fail to Reject")
# Out:
# Z-statistic = 1.9200
# P-value = 0.0549
# Reject Null hypothesis

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %% [markdown]
# A company claims that the average delivery time for its parcels is 48 hours. A random sample of 64 deliveries shows an average delivery time of 49.2 hours, with a known population standard deviation of 4 hours.
# At 5% significance level, test whether there is enough evidence to reject the company’s claim.

# %%
mu = 48
sigma = 4
x_bar = 49.2
n = 64

alpha = 0.05

z_stats = (x_bar - mu) / (sigma / (np.sqrt(n)))
print(f"Z Statistics: {z_stats.round(2)}")

z_critical = norm.ppf(1 - alpha/2 )
print(f"Z Critical: +- {z_critical.round(2)}")

print("------ Plotting on the Graph ------")
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x)

plt.figure(figsize=(15, 6))
plt.plot(x, y, color="blue", label="Z-Distribution")

left_critical = -z_critical
right_critical = z_critical

plt.axvline(left_critical, color="red", linestyle="--", label=f"Z Critical = ±{z_critical:.2f}")
plt.fill_between(x, y, where=(x <= left_critical), color="red", alpha=0.3)
plt.axvline(right_critical, color="red", linestyle="--")
plt.fill_between(x, y, where=(x >= right_critical), color="red", alpha=0.3)
plt.axvline(z_stats, color="black", linestyle="--", label=f"Z Stat = {z_stats:.2f}")

plt.title("Two-Tailed Z-Test")
plt.xlabel("Z-value")
plt.ylabel("Probability Density")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Z Statistics: 2.4
# Z Critical: +- 1.96
# ------ Plotting on the Graph ------

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2(mu0, mu1, sigma, n, alpha=0.05, alternative='two-sided'):

    # Standard error
    se = sigma / np.sqrt(n)

    # Critical z-values
    if alternative == 'two-sided':
        z_crit = norm.ppf(1 - alpha/2)
        z_left = -z_crit
        z_right = z_crit
    elif alternative == 'left':
        z_right = norm.ppf(alpha)
    elif alternative == 'right':
        z_right = norm.ppf(1 - alpha)

    # X ranges
    x = np.linspace(mu0 - 4*se, mu1 + 4*se, 1000)

    # Distributions under H0 and H1
    y0 = norm.pdf(x, mu0, se)
    y1 = norm.pdf(x, mu1, se)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y0, label='H₀ Distribution', color='blue')
    plt.plot(x, y1, label='H₁ Distribution', color='green')

    # Type I Error (red area)
    if alternative == 'two-sided':
        plt.fill_between(x, y0, where=(x <= mu0 + z_left * se), color='red', alpha=0.4, label='Type I Error (α)')
        plt.fill_between(x, y0, where=(x >= mu0 + z_right * se), color='red', alpha=0.4)
    elif alternative == 'right':
        plt.fill_between(x, y0, where=(x >= mu0 + z_right * se), color='red', alpha=0.4, label='Type I Error (α)')
    elif alternative == 'left':
        plt.fill_between(x, y0, where=(x <= mu0 + z_right * se), color='red', alpha=0.4, label='Type I Error (α)')

    # Type II Error (blue area under H₁)
    if alternative == 'two-sided':
        beta = norm.cdf(mu0 + z_right * se, mu1, se) - norm.cdf(mu0 + z_left * se, mu1, se)
        plt.fill_between(x, y1, where=((x >= mu0 + z_left * se) & (x <= mu0 + z_right * se)), color='purple', alpha=0.3, label='Type II Error (β)')
    elif alternative == 'right':
        beta = norm.cdf(mu0 + z_right * se, mu1, se)
        plt.fill_between(x, y1, where=(x <= mu0 + z_right * se), color='purple', alpha=0.3, label='Type II Error (β)')
    elif alternative == 'left':
        beta = 1 - norm.cdf(mu0 + z_right * se, mu1, se)
        plt.fill_between(x, y1, where=(x >= mu0 + z_right * se), color='purple', alpha=0.3, label='Type II Error (β)')

    plt.title("Type I (α) and Type II (β) Errors")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

    print(f"→ Type II Error (β): {beta:.4f}")
    print(f"→ Power of the test (1 - β): {1 - beta:.4f}")

visualize_type1_type2(70, 75, 2, 64, 0.05)
# Out:
# → Type II Error (β): 0.0000
# → Power of the test (1 - β): 1.0000

# %% [markdown]
# 6. Write a Python program to perform an independent T-test and interpret the results.

# %%
from scipy.stats import t

mu = 75
x_bar = 76.8
s = 3
n = 16
df = n - 1
alpha = 0.05

t_stats = (x_bar - mu) / (s / np.sqrt(n))
print(f"T Stats: {t_stats.round(2)}")

t_critical_right = t.ppf(1 - alpha/2, df=df)
t_critical_left = t.ppf(alpha/2, df=df)
print(f"For Positive Critical Value: {t_critical_right.round(2)}")

if t_stats > t_critical_right:
    print("--->> Reject Null Hypothesis")
else:
    print("--->> Fail to Reject Null Hypothesis")
# Out:
# T Stats: 2.4
# For Positive Critical Value: 2.13
# --->> Reject Null Hypothesis

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel

before = np.array([120, 122, 121, 119, 124, 118, 117, 123, 122, 121])
after  = np.array([115, 118, 117, 116, 119, 115, 114, 120, 118, 117])

# Paired t-test
t_stat, p_value = ttest_rel(before, after)

# Output results
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("→ Reject H₀: Significant difference (treatment effect).")
else:
    print("→ Fail to reject H₀: No significant difference.")

# Bar plot to show before vs after for each patient
plt.figure(figsize=(10, 6))
index = np.arange(len(before))
bar_width = 0.35

plt.bar(index, before, bar_width, label='Before', color='skyblue')
plt.bar(index + bar_width, after, bar_width, label='After', color='lightgreen')

plt.xlabel('Patient')
plt.ylabel('Measurement')
plt.title('Before vs After Treatment')
plt.xticks(index + bar_width / 2, [f'P{i+1}' for i in index])
plt.legend()
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# T-Statistic: 15.2339
# P-value: 0.0000
# → Reject H₀: Significant difference (treatment effect).

# %% [markdown]
# 8.

# %%
import numpy as np
from scipy.stats import norm, ttest_1samp
import matplotlib.pyplot as plt

# Simulated population parameters
population_mean = 50
population_sigma = 10  
np.random.seed(42)

# Simulated sample data
n = 25
sample = np.random.normal(loc=52, scale=10, size=n)  

# --- Z-test ---
sample_mean = np.mean(sample)
standard_error_z = population_sigma / np.sqrt(n)
z_stat = (sample_mean - population_mean) / standard_error_z
p_value_z = 2 * (1 - norm.cdf(abs(z_stat)))

# --- T-test ---
t_stat, p_value_t = ttest_1samp(sample, popmean=population_mean)

# --- Print results ---
print("Sample Mean:", round(sample_mean, 2))
print("\n--- Z-Test (σ known) ---")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value_z:.4f}")

print("\n--- T-Test (σ unknown) ---")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value_t:.4f}")
# Out:
# Sample Mean: 50.36
#
# --- Z-Test (σ known) ---
# Z-statistic: 0.1825
# P-value: 0.8552
#
# --- T-Test (σ unknown) ---
# T-statistic: 0.1907
# P-value: 0.8503

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
from scipy.stats import norm

def confidence_inteval_calculator():
    base_value = float(input("Please Enter the value which you want to get CI: "))
    alpha = float(input("Please Enter the value Level of significane for CI: "))
    standard_deviation  = float(input("Please Enter the Standard Deviation for CI: "))
    n = float(input("Please Enter the number of data points for CI: "))

    z_val = norm.ppf(1 - alpha/2).round(2)

    MoE = z_val * standard_deviation / np.sqrt(n)

    lower_band = int(base_value-MoE)
    upper_band = int(base_value+MoE)

    interval = [lower_band, upper_band]
    print(f"CI: {interval}")
    print("There can be values present in this interval")



confidence_inteval_calculator()
# Out:
# CI: [24008, 24792]

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data

# %%
def confidence_inteval_calculator():
    base_value = float(input("Please Enter the value which you want to get CI: "))
    alpha = float(input("Please Enter the value Level of significane for CI: "))
    standard_deviation  = float(input("Please Enter the Standard Deviation for CI: "))
    n = float(input("Please Enter the number of data points for CI: "))

    z_val = norm.ppf(1 - alpha/2).round(2)

    MoE = z_val * standard_deviation / np.sqrt(n)

    lower_band = int(base_value-MoE)
    upper_band = int(base_value+MoE)

    interval = [lower_band, upper_band]
    print(f"MOE: +-{MoE}")
 
confidence_inteval_calculator()
# Out:
# MOE: +-392.0

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# %%
def bayesian_inference():
    # Given:
    P_D = 0.01           
    P_not_D = 1 - P_D     # Probability of no disease

    P_Pos_given_D = 0.99  # True positive rate
    P_Pos_given_not_D = 0.05  # False positive rate

    # Total probability of testing positive
    P_Pos = (P_Pos_given_D * P_D) + (P_Pos_given_not_D * P_not_D)

    # Apply Bayes' Theorem
    P_D_given_Pos = (P_Pos_given_D * P_D) / P_Pos

    print(f"Probability you actually have the disease given a positive test: {P_D_given_Pos:.4f} ({P_D_given_Pos*100:.2f}%)")

bayesian_inference()
# Out:
# Probability you actually have the disease given a positive test: 0.1667 (16.67%)

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

data = pd.DataFrame({
    'Tea':   [20, 30, 10],   
    'Coffee': [15, 25, 20]
}, index=['Young', 'Adult', 'Senior'])

print("Contingency Table:\n")
print(data)

# Perform Chi-Square Test
chi2_stat, p_value, dof, expected = chi2_contingency(data)

print("\nChi-Square Statistic:", round(chi2_stat, 4))
print("Degrees of Freedom:", dof)
print("P-Value:", round(p_value, 4))
print("\nExpected Frequencies:\n", pd.DataFrame(expected, index=data.index, columns=data.columns))

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("\nResult: Reject H₀ → There IS a significant relationship between Age and Drink Preference.")
else:
    print("\nResult: Fail to reject H₀ → No significant relationship between Age and Drink Preference.")
# Out:
# Contingency Table:
#
#         Tea  Coffee
# Young    20      15
# Adult    30      25
# Senior   10      20
#
# Chi-Square Statistic: 4.5022
# Degrees of Freedom: 2
# P-Value: 0.1053
#
# Expected Frequencies:
#           Tea  Coffee
# Young   17.5    17.5
# Adult   27.5    27.5
# Senior  15.0    15.0
#
# Result: Fail to reject H₀ → No significant relationship between Age and Drink Preference.

# %% [markdown]
# 13.Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

data = pd.DataFrame({
    'Tea':   [20, 30, 10],   
    'Coffee': [15, 25, 20]
}, index=['Young', 'Adult', 'Senior'])

print("Contingency Table:\n")
print(data)

# Perform Chi-Square Test
chi2_stat, p_value, dof, expected = chi2_contingency(data)

# print("\nChi-Square Statistic:", round(chi2_stat, 4))
# print("Degrees of Freedom:", dof)
# print("P-Value:", round(p_value, 4))
print("\nExpected Frequencies:\n", pd.DataFrame(expected, index=data.index, columns=data.columns))

# # Interpretation
# alpha = 0.05
# if p_value < alpha:
#     print("\nResult: Reject H₀ → There IS a significant relationship between Age and Drink Preference.")
# else:
#     print("\nResult: Fail to reject H₀ → No significant relationship between Age and Drink Preference.")
# Out:
# Contingency Table:
#
#         Tea  Coffee
# Young    20      15
# Adult    30      25
# Senior   10      20
#
# Expected Frequencies:
#           Tea  Coffee
# Young   17.5    17.5
# Adult   27.5    27.5
# Senior  15.0    15.0

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import chi2

data_points = ['1', '2', '3', '4', '5', '6']
observed = np.array([16, 5, 11, 16, 5, 7])
expected = np.array([10, 10, 10, 10, 10, 10])
df = len(data_points) - 1
alpha = 0.05


chi2_stats = sum((observed - expected)**2/expected)
chi2_critical = chi2.ppf(1 - alpha, df)
x = np.linspace(0, 15, 500)
y = chi2.pdf(x, df)

print(f"Chi-Square Stats: {chi2_stats.round(2)}")
print(f"Chi-Square Critical: {chi2_critical.round(2)}")

if chi2_stats > chi2_critical:
    print("--> Reject the null hypothesis")
else:
    print("--> Fail to Reject the null hypothesis")
# Out:
# Chi-Square Stats: 13.2
# Chi-Square Critical: 11.07
# --> Reject the null hypothesis

# %% [markdown]
# 15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

# %%
plt.plot(x, y, color="blue", label="Chi-Square Distribution")

plt.axvline(chi2_stats, linestyle="--", color="black", label="Chi-Square Stats Value")
plt.axvline(chi2_critical, linestyle="--", color="red", label="Chi-Square Critical Value")
plt.fill_between(x, y, where=(x >= chi2_critical), color="red", alpha=0.4, label="Critical Area")

plt.xlabel('Chi-Square Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.title("Chi_Square Distribution Plot")
plt.legend()
plt.show()

# %% [markdown]
# 16. Implement an F-test using Python to compare the variances of two random samples

# %%
import numpy as np
from scipy.stats import f

np.random.seed(0)
sample1 = np.random.normal(loc=10, scale=3, size=30)
sample2 = np.random.normal(loc=10, scale=2, size=25)

var1 = np.var(sample1, ddof=1)
var2 = np.var(sample2, ddof=1)

n1, n2 = len(sample1), len(sample2)
df1, df2 = n1 - 1, n2 - 1

if var1 > var2:
    F = var1 / var2
    df_num, df_den = df1, df2
else:
    F = var2 / var1
    df_num, df_den = df2, df1

p_value = 2 * min(f.cdf(F, df_num, df_den), 1 - f.cdf(F, df_num, df_den))

print(f"Variance 1: {var1:.4f}")
print(f"Variance 2: {var2:.4f}")
print(f"F-statistic: {F:.4f}")
print(f"Degrees of freedom: ({df_num}, {df_den})")
print(f"P-value (two-tailed): {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("--> Reject H₀: Variances are significantly different.")
else:
    print("--> Fail to reject H₀: No significant difference in variances.")
# Out:
# Variance 1: 10.8965
# Variance 2: 3.8433
# F-statistic: 2.8352
# Degrees of freedom: (29, 24)
# P-value (two-tailed): 0.0111
# --> Reject H₀: Variances are significantly different.

# %% [markdown]
# 17. Write a Python program to perform an ANOVA test to compare means between multiple groups and
# interpret the results

# %%
import numpy as np
from scipy.stats import f_oneway
import matplotlib.pyplot as plt

np.random.seed(42)
group1 = np.random.normal(loc=75, scale=5, size=20) 
group2 = np.random.normal(loc=78, scale=5, size=20) 
group3 = np.random.normal(loc=82, scale=5, size=20) 

f_stat, p_value = f_oneway(group1, group2, group3)

print("=== One-Way ANOVA Results ===")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("--> Reject H₀: At least one group mean is significantly different.")
else:
    print("--> Fail to reject H₀: No significant difference between group means.")
# Out:
# === One-Way ANOVA Results ===
# F-statistic: 14.6938
# P-value: 0.0000
# --> Reject H₀: At least one group mean is significantly different.

# %% [markdown]
# 18.  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

# %%
plt.boxplot([group1, group2, group3], labels=['Class A', 'Class B', 'Class C'])
plt.title('Score Comparison Across Classes')
plt.ylabel('Test Scores')
plt.grid(True)
plt.show()

# %% [markdown]
# 19.  Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

# %%
import numpy as np
import pandas as pd
from scipy.stats import shapiro, levene, f_oneway
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(0)
group_A = np.random.normal(loc=70, scale=5, size=30)
group_B = np.random.normal(loc=72, scale=5, size=30)
group_C = np.random.normal(loc=74, scale=5, size=30)

groups = [group_A, group_B, group_C]
group_labels = ['A']*30 + ['B']*30 + ['C']*30
all_data = np.concatenate(groups)


print("=== Checking Assumptions ===")

for i, group in enumerate(groups):
    stat, p = shapiro(group)
    print(f"Group {chr(65+i)} - Shapiro-Wilk p = {p:.4f} →", "Normal" if p > 0.05 else "Not Normal")

stat, p = levene(*groups)
print(f"\nLevene’s Test p = {p:.4f} →", "Equal Variance" if p > 0.05 else "Unequal Variance")

print("\nIndependence: Assumed based on study design.")

f_stat, p_value = f_oneway(*groups)
print(f"\n=== One-Way ANOVA ===")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_value:.4f}")
if p_value < 0.05:
    print("Reject H₀ → At least one group mean is significantly different.")
else:
    print("Fail to reject H₀ → No significant difference between group means.")

df = pd.DataFrame({'Score': all_data, 'Group': group_labels})
plt.figure(figsize=(8, 5))
sns.boxplot(x='Group', y='Score', data=df)
plt.title('One-Way ANOVA: Group Score Comparison')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# === Checking Assumptions ===
# Group A - Shapiro-Wilk p = 0.5254 → Normal
# Group B - Shapiro-Wilk p = 0.9085 → Normal
# Group C - Shapiro-Wilk p = 0.7204 → Normal
#
# Levene’s Test p = 0.6758 → Equal Variance
#
# Independence: Assumed based on study design.
#
# === One-Way ANOVA ===
# F-statistic: 2.3640
# P-value: 0.1001
# Fail to reject H₀ → No significant difference between group means.

# %% [markdown]
# 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
# results

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

np.random.seed(1)
data = pd.DataFrame({
    'Score': np.random.normal(70, 5, 60),
    'Method': ['Online']*20 + ['Offline']*20 + ['Hybrid']*20,
    'Gender': (['Male', 'Female']*10)*3
})

# Add variation by method and gender
data.loc[data['Method'] == 'Offline', 'Score'] += 3
data.loc[data['Gender'] == 'Female', 'Score'] += 2
data.loc[(data['Method'] == 'Hybrid') & (data['Gender'] == 'Female'), 'Score'] += 2

#Two-Way ANOVA using statsmodels
model = ols('Score ~ C(Method) + C(Gender) + C(Method):C(Gender)', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print("=== Two-Way ANOVA Results ===\n")
print(anova_table)

# Step 3: Visualization - Interaction Plot
plt.figure(figsize=(8, 5))
sns.pointplot(data=data, x='Method', y='Score', hue='Gender', dodge=True, markers=['o', 's'], capsize=0.1   )
plt.title('Interaction Plot: Method vs Gender on Score')
plt.grid(True, linestyle='--', alpha=0.5)
plt.ylabel("Mean Score")
plt.show()
# Out:
# === Two-Way ANOVA Results ===
#
#                          sum_sq    df          F    PR(>F)
# C(Method)            130.686850   2.0   3.752754  0.029782
# C(Gender)             23.827532   1.0   1.368445  0.247217
# C(Method):C(Gender)  379.236137   2.0  10.890000  0.000106
# Residual             940.254895  54.0        NaN       NaN

# %% [markdown]
# 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

# %% [markdown]
# A fitness coach wants to compare the effectiveness of three workout programs (Program A, B, and C) on weight loss (in kg) over 4 weeks. The data collected is:
#
# Program A: [2.5, 2.9, 2.7]	Program B: [3.0, 2.8, 3.2]	Program C: [4.2, 3.9, 4.0]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f, f_oneway

a = [2.5, 2.9, 2.7]
b = [3.0, 2.8, 3.2]
c = [4.2, 3.9, 4.0]

groups = [a, b, c]

k = len(groups)
N = sum(len(group) for group in groups)
df1 = k - 1
df2 = N - k

f_stat, p_value = f_oneway(*groups)
alpha = 0.05

f_critical = f.ppf(1 - alpha, dfn=df1, dfd=df2)


x = np.linspace(0, 40, 50)
y = f.pdf(x, dfn=df1, dfd=df2)


plt.figure(figsize=(10, 6))
plt.plot(x, y, label='F-distribution', color='blue')
plt.axvline(f_stat, color="black", linestyle="--", label=f'F-stat = {f_stat:.2f}')
plt.axvline(f_critical, color="red", linestyle="--", label=f'F-stat = {f_critical:.2f}')

plt.legend()
plt.show()

# %% [markdown]
# 22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

np.random.seed(0)
group_A = np.random.normal(loc=75, scale=5, size=30)  # Method A
group_B = np.random.normal(loc=78, scale=5, size=30)  # Method B
group_C = np.random.normal(loc=80, scale=5, size=30)  # Method C

df = pd.DataFrame({
    'Score': np.concatenate([group_A, group_B, group_C]),
    'Group': ['A']*30 + ['B']*30 + ['C']*30
})

f_stat, p_val = f_oneway(group_A, group_B, group_C)

print("=== One-Way ANOVA Result ===")
print(f"F-statistic: {f_stat:.4f}")
print(f"P-value: {p_val:.4f}")
if p_val < 0.05:
    print("Reject H₀: At least one group mean is significantly different.")
else:
    print("Fail to reject H₀: No significant difference between group means.")

plt.figure(figsize=(8, 5))
sns.boxplot(x='Group', y='Score', data=df, palette='Set2')
plt.title('Group-wise Score Comparison (One-Way ANOVA)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylabel("Score")
plt.xlabel("Group")
plt.show()
# Out:
# === One-Way ANOVA Result ===
# F-statistic: 2.5474
# P-value: 0.0841
# Fail to reject H₀: No significant difference between group means.

# %% [markdown]
# 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

# %%
import numpy as np
from scipy.stats import ttest_1samp, norm
import matplotlib.pyplot as plt

np.random.seed(1)
sample = np.random.normal(loc=52, scale=5, size=30) 

population_mean = 50

t_stat, p_value = ttest_1samp(sample, population_mean)

print("=== One-Sample T-Test ===")
print(f"Sample Mean: {np.mean(sample):.2f}")
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀ → Sample mean is significantly different from population mean.")
else:
    print("Fail to reject H₀ → No significant difference in means.")

plt.figure(figsize=(8, 5))
plt.hist(sample, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(np.mean(sample), color='blue', linestyle='--', label='Sample Mean')
plt.axvline(population_mean, color='red', linestyle='--', label='Population Mean')
plt.title('Sample Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# === One-Sample T-Test ===
# Sample Mean: 51.70
# T-statistic: 1.8147
# P-value: 0.0799
# Fail to reject H₀ → No significant difference in means.

# %% [markdown]
# 24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

# %%
import numpy as np
from scipy.stats import chi2


np.random.seed(42)
data = np.random.normal(loc=50, scale=5, size=25) 

sigma_0_squared = 25 

n = len(data)
sample_var = np.var(data, ddof=1)
chi2_stat = (n - 1) * sample_var / sigma_0_squared

alpha = 0.05
chi2_critical_low = chi2.ppf(alpha / 2, df=n - 1)
chi2_critical_high = chi2.ppf(1 - alpha / 2, df=n - 1)

print("=== Chi-Square Test for Variance ===")
print(f"Sample Variance: {sample_var:.4f}")
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"Critical Region: < {chi2_critical_low:.4f} or > {chi2_critical_high:.4f}")

if chi2_stat < chi2_critical_low or chi2_stat > chi2_critical_high:
    print("Reject H₀ → Population variance is significantly different.")
else:
    print("Fail to reject H₀ → No significant difference in variance.")
# Out:
# === Chi-Square Test for Variance ===
# Sample Variance: 22.8748
# Chi-Square Statistic: 21.9598
# Critical Region: < 12.4012 or > 39.3641
# Fail to reject H₀ → No significant difference in variance.

# %% [markdown]
# 25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

# %%
from statsmodels.stats.proportion import proportions_ztest
import numpy as np

successes = np.array([56, 30]) 
samples = np.array([200, 150])

z_stat, p_value = proportions_ztest(successes, samples)

print("=== Two-Proportion Z-Test ===")
print(f"Z-statistic: {z_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀ → Proportions are significantly different.")
else:
    print("Fail to reject H₀ → No significant difference in proportions.")
# Out:
# === Two-Proportion Z-Test ===
# Z-statistic: 1.7204
# P-value: 0.0854
# Fail to reject H₀ → No significant difference in proportions.

# %% [markdown]
# 26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the resultsD

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

np.random.seed(42)
group1 = np.random.normal(loc=50, scale=5, size=30)   
group2 = np.random.normal(loc=50, scale=8, size=30)

var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

if var1 > var2:
    F = var1 / var2
    df1, df2 = len(group1) - 1, len(group2) - 1
else:
    F = var2 / var1
    df1, df2 = len(group2) - 1, len(group1) - 1

alpha = 0.05
f_critical_low = f.ppf(alpha / 2, df1, df2)
f_critical_high = f.ppf(1 - alpha / 2, df1, df2)
p_value = 2 * min(f.cdf(F, df1, df2), 1 - f.cdf(F, df1, df2))

# Step 5: Print results
print("=== F-Test for Variance ===")
print(f"Variance 1: {var1:.4f}")
print(f"Variance 2: {var2:.4f}")
print(f"F-statistic: {F:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"Critical Region: F < {f_critical_low:.4f} or F > {f_critical_high:.4f}")

if F < f_critical_low or F > f_critical_high:
    print("Reject H₀: Variances are significantly different.")
else:
    print("Fail to reject H₀: No significant difference in variances.")

x = np.linspace(0.1, 5, 500)
y = f.pdf(x, df1, df2)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='F-distribution', color='blue')
plt.axvline(F, color='black', linestyle='--', label=f'F = {F:.2f}')
plt.axvline(f_critical_low, color='red', linestyle='--', label='Lower Critical Value')
plt.axvline(f_critical_high, color='red', linestyle='--', label='Upper Critical Value')
plt.fill_between(x, y, where=(x < f_critical_low) | (x > f_critical_high), color='red', alpha=0.3, label='Rejection Region')
plt.title('F-Test: Comparing Two Variances')
plt.xlabel('F Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# === F-Test for Variance ===
# Variance 1: 20.2503
# Variance 2: 55.4849
# F-statistic: 2.7400
# P-value: 0.0084
# Critical Region: F < 0.4760 or F > 2.1010
# Reject H₀: Variances are significantly different.

# %% [markdown]
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results

# %%
import numpy as np
from scipy.stats import chisquare
import matplotlib.pyplot as plt

observed = np.array([10, 8, 9, 12, 11, 10])

expected = np.full_like(observed, fill_value=np.sum(observed) / len(observed))

chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print("=== Chi-Square Goodness of Fit Test ===")
print(f"Observed: {observed}")
print(f"Expected: {expected}")
print(f"Chi-Square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀ → Observed data does NOT fit the expected distribution.")
else:
    print("Fail to reject H₀ → Observed data fits the expected distribution.")


labels = ['1', '2', '3', '4', '5', '6']
x = np.arange(len(labels))

plt.bar(x - 0.2, observed, width=0.4, label='Observed', color='skyblue')
plt.bar(x + 0.2, expected, width=0.4, label='Expected', color='orange')
plt.xticks(x, labels)
plt.title('Observed vs Expected Frequencies')
plt.ylabel('Frequency')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# === Chi-Square Goodness of Fit Test ===
# Observed: [10  8  9 12 11 10]
# Expected: [10 10 10 10 10 10]
# Chi-Square Statistic: 1.0000
# P-value: 0.9626
# Fail to reject H₀ → Observed data fits the expected distribution.
